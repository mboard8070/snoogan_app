# %%
'''
# Navigate to the Snoogans empire
cd ~/nvidia-workbench/snoogan_app

# Point Ollama ONLY at our wholesome project models (supertrader_final stays pure forever)
export OLLAMA_MODELS=$(pwd)/models

# Fire up the server quiet (no need for OLLAMA_HOST bullshit anymore)
ollama serve > /dev/null 2>&1 &

# Wait a sec for it to wake up zen
sleep 10

# Register the Red Bank degenerate brain once (skips if already chillin')
ollama create snoogans -f models/supertrader_final/modelfile_snoogans || true

# Activate the venv with all the goodies
source venv/bin/activate

# Launch the pretty Streamlit face headless on port 8501
streamlit run app.py --server.port=8501 --server.headless=true

# or your alias 'spark' if you kept it
ssh -L 8501:localhost:8501 mboard76@100.107.132.16 
'''
# Out:
#   Cell In[1], line 2
#     cd ~/nvidia-workbench/snoogan_app
#        ^
# SyntaxError: invalid syntax

# %%
react quick start
  To start on Monday:
  cd /home/mboard76/nvidia-workbench/snoogan_app
  ./start.sh

  To stop:
  ./stop.sh

  The start script will:
  1. Kill any existing processes on ports 5173/8000
  2. Activate the Python venv
  3. Start the FastAPI backend (port 8000)
  4. Start the React frontend (port 5173)
  5. Save logs to logs/backend.log and logs/frontend.log
  6. Print the SSH tunnel command you need to run from your local machine

  From your local machine, run:
  ssh -L 5173:localhost:5173 -L 8000:localhost:8000 mboard76@100.107.132.16

  Then open http://localhost:5173 in your browser.

# %%
 Here are the steps to get the React dashboard running:

  1. SSH into your server
  ssh mboard76@100.107.132.16

  2. Navigate to the project
  cd /home/mboard76/nvidia-workbench/snoogan_app

  3. Start the FastAPI backend
  cd backend
  source venv/bin/activate  # if using a virtual environment
  python main.py
  (or however your backend is started - runs on port 8000)

  4. Start the React frontend (in a new terminal)
  cd /home/mboard76/nvidia-workbench/snoogan_app/frontend
  npm run dev
  (runs on port 5173)

  5. Set up SSH tunneling (from your local machine)
  ssh -L 5173:localhost:5173 -L 8000:localhost:8000 mboard76@100.107.132.16

  6. Open in browser
  http://localhost:5173
# Out:
#   Cell In[1], line 1
#     '''
#     ^
# SyntaxError: incomplete input

# %%
# Out:
#   Cell In[2], line 1
#     '''
#     ^
# SyntaxError: incomplete input
