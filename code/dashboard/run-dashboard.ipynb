# %%
'''
./start-dashboard.sh
./stop-dashboard.sh

ssh -L 8501:localhost:8501 spark  ### add forward command in macbook shell
'''
# Out:
# '\n./start-dashboard.sh\n./stop-dashboard.sh\n'

# %%
'''
#start ollama
OLLAMA_HOST=0.0.0.0 ollama serve &

#stop ollama
sudo systemctl stop ollama

ollama run supertrader:latest

# %%
'''
#activate the venve located in dashboard in case we need to install packages
source venv/bin/activate
