# %%
# Run this in a Jupyter/VS Code notebook cell
import subprocess
import sys

# This will launch the Streamlit dashboard in a new tab automatically
subprocess.run([sys.executable, "-m", "streamlit", "run", "app.py"])
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.18.0.3:8501
#   External URL: http://173.81.22.72:8501

# %%
"""
ssh spark                               # one time per day, auto-forwards 8501
cd ~/nvidia-workbench/snoogan_app/code/dashboard
source venv/bin/activate                # takes 0.3 seconds
streamlit run app.py                    # prints the clickable link
"""
