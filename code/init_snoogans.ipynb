# %%
import os

# Create the bot folder inside app
os.makedirs("app/bot", exist_ok=True)

# Create the empty bot.py file (we'll fill it in next)
open("app/bot/__init__.py", "a").close()
open("app/bot/bot.py", "w").write("""# bot.py - Snoogans lives here
class Snoogans:
    def chat(self, message):
        return "Yo yo yo, what’s up you beautiful degenerate? Snoogans here, just sold another tiny spread, lunch money secured, snoochie boochies."
snoogans = Snoogans()
""")
print("✓ bot folder and bot.py created – Snoogans is now home")
# Out:
# ✓ bot folder and bot.py created – Snoogans is now home

# %%
import sys
sys.path.insert(0, "/workbench")
print("✓ Project path fixed")
# Out:
# ✓ Project path fixed

# %%
from app.bot.bot import snoogans
print("🦝 SNOOGANS WAKES UP:")
print(snoogans.chat("hey"))
# Out:
# 🦝 SNOOGANS WAKES UP:
# Yo yo yo, what’s up you beautiful degenerate? Snoogans here, just sold another tiny spread, lunch money secured, snoochie boochies.

# %%
# Cell 4 – THE MOMENT WE’VE BEEN WAITING FOR
print("🦝 SNOOGANS, WAKE UP AND TALK TO ME:")
print(snoogans.chat("hey"))
# Out:
# 🦝 SNOOGANS, WAKE UP AND TALK TO ME:
# Yo yo yo, what’s up you beautiful degenerate? Snoogans here, just sold another tiny spread, lunch money secured, snoochie boochies.
